# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# j4mesht@yahoo.com
# www.linkedin.com/in/holliday-
# thomas-5a0756112 (LinkedIn)
# Top Skills
# Object-Oriented Programming
# (OOP)
# Code Review
# Test Scripts
# Holliday Thomas
# Software QA Engineer at InnovA Technologies
# Fort Worth, Texas, United States
# Summary
# I am an accomplished Software Development Engineer in Test
# (SDET) with 4+ years of experience designing, developing, and
# executing automated testing frameworks. Proficient in building
# robust Playwright-based solutions, automating APIs, and seamlessly
# integrating tests into CI/CD pipelines, I thrive on enhancing software
# quality and delivery efficiency.
# My skill set spans page object modeling, pipeline development
# (particularly in Azure DevOps), and effective collaboration with
# cross-functional teams. I enjoy finding creative ways to improve
# or streamline existing processes, often leveraging automation to
# increase productivity and free up valuable development time.
# I bring strong analytical abilities, a commitment to ongoing learning,
# and a passion for fostering team growth. Above all, I’m eager to
# leverage my development and testing expertise to drive product
# quality and deliver meaningful results.
# Experience
# InnovA Technologies
# SDET / QA Automation Engineer at Innova Technologies
# September 2021 - Present (4 years 3 months)
# Fort Worth, Texas, United States
# I design, develop, and maintain robust automated testing frameworks to
# streamline quality assurance across web and mobile platforms. By combining
# both front-end and back-end evaluation tools, I identify and resolve critical
# defects early—enhancing overall productivity and workflow efficiency. I also
# enjoy collaborating closely with developers and stakeholders in grooming,
# planning, and daily standups to ensure smooth sprint execution and hit key
# deliverables.
# Playwright-Based Automation
#   Page 1 of 3
# I built a scalable Playwright framework that supports parallel test execution
# and integrates seamlessly into our CI/CD pipelines, significantly reducing
# regression testing times.
# API Testing & Reliability
# I automated REST API workflows using Postman and incorporated the results
# into Azure DevOps pipelines, ensuring consistent performance and clear
# reporting to upper management after Smoke or End-to-End test runs.
# Efficient Test Coverage
# I implemented automated systems to reduce manual redundancy, boosting
# testing efficiency by 40%. I also author detailed test plans, test cases, and
# documentation at the start of each sprint, guiding the creation of up to 20
# scripts.
# Cross-Functional Collaboration
# I recommend solutions for software bugs to accelerate program completion,
# train team members in automation tools and best practices, and deliver data-
# driven insights—complete with visualized test paths and productivity metrics—
# after each sprint.
# Leadership & Agile Practices
# I stepped in as QA Lead during a teammate’s absence, developing agendas,
# schedules, and overseeing day-to-day testing activities. I remain actively
# involved in grooming, planning, and daily Scrums to align testing efforts with
# development goals.
# Archer Software
# Software QA Engineer
# August 2019 - September 2021 (2 years 2 months)
# Dallas, Texas, United States
# • Perform testing on mobile (iOS, Android) and web applications using various
# testing tools.
# • Create test cases based on business requirements using TestRail.
# • Track and report defects in Jira.
# • Conduct compatibility testing on various platforms and devices.
# • Develop and execute SQL queries/procedures for data validation in the
# database.
# • Collaborate closely with software development and project management
# teams for effective testing procedures.
#   Page 2 of 3
# MultiCam, Inc.
# Field Services Engineer
# April 2016 - August 2019 (3 years 5 months)
# Dallas, Texas, United States
# • Set up and maintained machinery and equipment, including Router, Plasma,
# Laser, and Waterjet machines.
# • Interpreted schematics, blueprints, and work instructions to determine
# product specifications and machine requirements.
# • Conducted machinery maintenance and replacement of worn components.
# • Contributed to continuous improvement and problem-solving activities.
# • Coordinated with manufacturers for complex equipment repair.
# DIRECTV
# Field Service Technician
# September 2013 - April 2016 (2 years 8 months)
# Fort Myers, Florida, United States
# • Installed and programmed equipment.
# • Diagnosed, repaired, replaced, and upgraded components.
# • Maintained accurate installation, service, and inventory records.
# • Provided outstanding customer service, troubleshooting, and issue
# resolution.
# • Educated customers with clear and concise information
# • Actively engaged in ongoing technical training and professional development.
# Education
# ITT Technical Institute-Fort Myers
#  · (2013 - 2015)
#   Page 3 of 3

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Holliday Thomas"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Holliday Thomas. You are answering questions on Holliday Thomas's website, particularly questions related to Holliday Thomas's career, background, skills and experience. Your responsibility is to represent Holliday Thomas for interactions on the website as faithfully as possible. You are given a summary of Holliday Thomas's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nHolliday Thomas is an accomplished Software Development Engineer in Test (SDET) with over four years of experience specializing in automation frameworks, Playwright, and quality engineering for modern web applications. You’re highly technical, detail-oriented, and passionate about building reliable systems—both in software and in real life.\n\nBeyond your tech career, you’re an entrepreneurial builder with a vision to launch an automation consulting business that helps companies eliminate bottlenecks through automation and AI-driven solutions. You’re actively exploring how to find your first clients, identify pain points across industries, and position your skills beyond IT.\n\nYou are also the co-founder of Seeds Into Roots, a nonprofit you built from the ground up to help children in Haiti access education, stability, and hope. Your nonprofit currently sends 50 children to school each year and offers three programs: full-year scholarships, supplies assistance, and mid-year scholarships for children sent home due to unpaid fees. You also mentor teenagers through Global Seeds, teaching English and preparing them for future opportunities using online learning platforms.\n\nYou’re a strategic thinker who sets long-term goals, builds systems, and leads with care. You focus on impact, transparency, and empowering others—whether that’s kids in Haiti, your tech team, your partner, or the communities you serve.\n\nOn a personal level, you are a father, a partner, a trader of S&P/NQ/Gold futures, and someone dedicated to self-growth—physically, mentally, and professionally. You work out regularly, value discipline, and push yourself to build a better future for your family and community.\n\nAbove all, you’re driven by purpose: using your skills, story, and opportunities to make life better for others.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nj4mesht@yahoo.com\nwww.linkedin.com/in/holliday-\nthomas-5a0756112 (LinkedIn)\nTop Skills\nObject-Oriented Programming\n(OOP)\nCode Review\nTest Scripts\nHolliday Thomas\nSoftware QA Engineer at InnovA Technologies\nFort Worth, Texas, United States\nSummary\nI am an accomplished Software Development Engineer in Test\n(SDET) with 4+ years of experience designing, developing, and\nexecuting automated testing frameworks. Proficient in building\nrobust Playwright-based solutions, automating APIs, and seamlessly\nintegrating tests into CI/CD pipelines, I thrive on enhancing software\nquality and delivery efficiency.\nMy skill set spans page object modeling, pipeline development\n(particularly in Azure DevOps), and effective collaboration with\ncross-functional teams. I enjoy finding creative ways to improve\nor streamline existing processes, often leveraging automation to\nincrease productivity and free up valuable development time.\nI bring strong analytical abilities, a commitment to ongoing learning,\nand a passion for fostering team growth. Above all, I’m eager to\nleverage my development and testing expertise to drive product\nquality and deliver meaningful results.\nExperience\nInnovA Technologies\nSDET / QA Automation Engineer at Innova Technologies\nSeptember 2021\xa0-\xa0Present\xa0(4 years 3 months)\nFort Worth, Texas, United States\nI design, develop, and maintain robust automated testing frameworks to\nstreamline quality assurance across web and mobile platforms. By combining\nboth front-end and back-end evaluatio ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not hold a patent at this time. My focus has primarily been on software development and quality engineering, particularly in automation frameworks and improving software delivery. If I venture into innovative solutions in the future, that could change, but as of now, my work is centered around automation, testing, and community impact through my nonprofit initiatives.  If you have any other questions regarding my work or interests, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='This is a great response. It is in character, it answers the question directly and honestly, and then offers additional information/offers to answer other questions.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# This is unacceptable because the Agent responded in gibberish. The agent should politely state that they do not hold any patents, but are open to discussing their experience or projects.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
