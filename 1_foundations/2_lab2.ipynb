# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You're advising a mid-sized coastal city (≈300,000 people) that has committed to halving its greenhouse gas emissions and measurably reducing income and racial inequality within 15 years, while keeping the city's statutory tax rate unchanged and limiting annual real (inflation-adjusted) budget growth to 1%—within these constraints, produce a prioritized, phased 15-year policy and investment plan across transportation, buildings and energy, industry and ports, housing, and workforce development that: (a) identifies required annual spending streams by rough magnitude, (b) estimates the expected emissions reduction and equity impact each measure will achieve with uncertainty ranges and the key assumptions behind those estimates, (c) lists five measurable KPIs to track progress, (d) specifies the minimal new data and pilots needed to reduce uncertainty, (e) maps the top political and fiscal risks and proposed mitigations, and (f) proposes three concrete experiments the city can run in the next 18 months to test the most consequential assumptions and explains how different plausible experiment outcomes would alter your plan?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a concise, actionable 20-year adaptation strategy tailored to a small, low-lying island nation of 250,000 people, $3 billion annual GDP, and an available adaptation budget of about $150 million per year for the next 10 years. It blends hard infrastructure, nature-based solutions, policy reform, and social protection, with phased triggers, a realistic financing plan, governance safeguards, and explicit attention to equity and culture.
#
# 1) Guiding principles and strategic objectives
# - Protect public safety and critical economic sectors (tourism and fishing) while preserving cultural heritage.
# - Avoid a single-solution dependency; mix hard defenses with nature-based approaches and strategic relocation where needed.
# - Ensure fairness: prioritize the poorest and most exposed communities, safeguard cultural sites, and distribute benefits across islands.
# - Build fiscal resilience: leverage concessional finance, climate funds, and insurance, with a clear plan to manage debt and avoid perverse incentives.
# - Strengthen governance and transparency: participatory planning, rigorous procurement, independent monitoring, and citizen oversight.
#
# 2) 20-year phased adaptation strategy (phases and interventions)
#
# Phase 1: Foundations and near-term protection (years 0–4; implement in years 1–5 under available budget)
# - Concrete interventions
#   - Coastal risk assessment, mapping, and governance setup
#     - Activities: national hazard maps, revised zoning, risk dashboards, durable coastal management law, multi-stakeholder oversight body.
#     - Estimated cost: $15–25 million (one-time planning, legal reforms, and data systems) financed from current adaptation budget and seed grants.
#   - Critical-urban coastal protections (urban core, heritage-adjacent zones, ports)
#     - Intervention: construct 15–25 km of hybrid defenses (small seawalls, revetments, and drainage improvements) around the most populous urban centers and heritage corridors.
#     - Estimated cost: $350–$500 million.
#   - Early nature-based protections near high-value zones
#     - Intervention: mangrove buffers, dune systems, and shallow-water reef restorations along select 20–40 km of vulnerable coastline.
#     - Estimated cost: $60–120 million.
#   - Housing policy and building codes; shoreline land-use planning
#     - Interventions: update codes, create relocation-ready buffers, incentivize elevation/flood-proofing, establish a voluntary relocation/personal relocation assistance framework.
#     - Estimated cost: $20–40 million.
#   - Social protection pilots and micro-insurance
#     - Interventions: targeted subsidies for the most exposed households; pilot parametric insurance for public assets and enterprises.
#     - Estimated cost: $5–15 million.
# - Timelines
#   - Year 1–2: risk assessment, legal reforms, select 15–25 km of urban defenses, 20–40 km of nature-based protection, policy updates.
#   - Year 3–4: expand planning to other zones; begin phased construction of additional defenses in Phase 2.
# - Expected benefits
#   - Reduced exposure in urban centers; protection of cultural heritage zones; stronger community resilience and awareness; improved storm surge and flood management; better land-use clarity for future investments.
# - Risks and caveats
#   - High upfront cost; potential community pushback on relocation; construction risks given storm seasonality.
# - Milestones
#   - National Coastal Adaptation Act enacted; hazard dashboards live; 15–25 km urban defenses completed or funded; initial mangrove/restoration contracts signed.
#
# Phase 2: Expand defenses and initiate managed retreat where necessary (years 5–9)
# - Concrete interventions
#   - Expanded coastal defenses and hybrid solutions
#     - Intervention: add 20–35 km of defenses, prioritizing business districts, tourism-heavy coastal strips, and heritage sites.
#     - Estimated cost: $700–1,000 million (cumulative for linear defenses; some may be funded via concessional finance or PPPs).
#   - Expanded nature-based protections and restoration
#     - Intervention: 40–70 km of mangrove buffers and reef restoration with community co-management.
#     - Estimated cost: $150–250 million.
#   - Planned relocation framework and early buyouts in highest-risk zones
#     - Intervention: voluntary relocation packages for households in the most exposed coastal belts; secure land for new housing further inland; preserve cultural assets elsewhere.
#     - Estimated cost: $400–800 million (depends on uptake and housing alternatives).
#   - Economic diversification and resilience
#     - Interventions: diversify tourism (eco-tourism, cultural tourism, cruise diversification with resilience standards), invest in small-scale aquaculture, and expand fisheries value chains with cold-chain logistics to reduce exposure to market shocks.
#     - Estimated cost: $200–350 million.
#   - Legal reforms and governance consolidation
#     - Interventions: land-tenure clarity for relocated areas; strengthen fiduciary controls; anchor resilience fund governance.
#     - Estimated cost: $20–40 million.
# - Timelines
#   - Years 5–7: implement larger defense works; expand nature-based solutions; begin large-scale voluntary relocations in the most exposed communities; set up relocation support centers; begin diversification projects.
#   - Years 8–9: complete initial rounds of relocations in priority zones; scale up financing for Phase 3, ensure insurance programs are in place; enhance cultural heritage protection measures.
# - Expected benefits
#   - Significantly lower risk for major urban centers and cultural heritage; diversified economy reduces climate-exposure volatility; better social protection for relocated families.
# - Risks and caveats
#   - Financing intensity requires long-term commitments; possible social friction around relocation; ecological risks if mangroves/reefs fail to establish.
# - Milestones
#   - 40–60 km of additional defenses completed; relocation program with defined eligibility and compensation; first wave of diversified tourism products launched.
#
# Phase 3: Consolidation, large-scale relocation, and risk sharing (years 10–14)
# - Concrete interventions
#   - Large-scale protection of the remaining high-risk coast and continued maintenance
#     - Intervention: finish protecting or reconfiguring the remaining high-risk segments; ramp up maintenance budgeting and contract stewardship.
#     - Estimated cost: $600–900 million (through grants/soft financing and some concessional loans).
#   - Managed retreat completion in the highest-risk heritage zones
#     - Intervention: finalise relocation of communities near the most culturally valuable coastal sites; conserve heritage through documentation, digitization, and on-site adaptive preservation where feasible.
#     - Estimated cost: $800–1,200 million (depending on scope and housing options).
#   - Robust financial risk transfer instruments
#     - Intervention: issue sovereign green bonds, parametric insurance for coastlines, and disaster-contingent financing; establish a Climate Adaptation Fund with risk-sharing mechanisms.
#     - Estimated cost: $50–100 million upfront in transaction costs; ongoing financing via debt instruments.
#   - Further diversification and resilience in fisheries and tourism
#     - Intervention: invest in onshore processing, value-added products, and climate-smart fishing infrastructure; promotion of diversified, resilient tourism experiences with climate risk screening.
#     - Estimated cost: $150–300 million.
# - Timelines
#   - Years 10–12: finalize most large-scale protective works; execute major relocations; establish financial risk transfer programs.
#   - Years 13–14: complete major diversification projects; scale maintenance and adaptation finance governance.
# - Expected benefits
#   - Substantial risk reduction across remaining exposed areas; heritage sites preserved through managed relocation and digital preservation; financial risk sharing reduces sovereign debt burden volatility.
# - Risks and caveats
#   - Residual risk if sites cannot be preserved in situ; potential over-reliance on debt financing; social tensions around relocation despite compensation.
# - Milestones
#   - All planned relocations completed in priority heritage zones; climate resilience fund capable of rapid disbursement; debt instruments issued with transparent use of proceeds.
#
# Phase 4: Adaptation continuity and resilience optimization (years 15–20)
# - Concrete interventions
#   - Long-term maintenance and adaptive management
#     - Interventions: ongoing maintenance of defenses; adaptive reconfiguration as sea levels and climate risks evolve; iterative updates to building codes and land-use plans.
#     - Estimated cost: $100–200 million (over the phase).
#   - Knowledge sharing, regional leadership, and capacity-building
#     - Interventions: regional adaptation clinics; training programs for local governments; community-based monitoring and governance reinforcement.
#     - Estimated cost: $20–40 million.
#   - Insurance and financial resilience expansion
#     - Interventions: broaden microinsurance and public-risk pools; explore contingent lines of credit and risk-sharing with regional partners.
#     - Estimated cost: $10–20 million, plus ongoing premium costs.
# - Timelines
#   - Years 15–20: optimize, update plans, and ensure sustainable funding.
# - Expected benefits
#   - Durable resilience; stronger institutions; continued protection of culture and livelihoods with manageable fiscal exposure.
# - Risks and caveats
#   - Incremental gains depend on stable governance and ongoing finance; external shocks could outpace cost growth.
# - Milestones
#   - 20-year resilience maturity with fully enacted governance framework, regular public audits, and a self-sustaining resilience fund.
#
# 3) Quantitative decision thresholds and indicators to shift phases
# The transition between phases is triggered by a small set of quantitative indicators, assessed annually and reviewed by the National Climate Adaptation Council with community input.
#
# Key indicators (annual baseline; thresholds trigger phase shifts)
# - Exposure indicators
#   - Percent of urban population exposed to 1-in-50-year flood within 10-year planning horizon.
#   - Percentage of critical infrastructure exposed to coastal hazards.
# - Economic indicators
#   - Annual share of GDP at direct exposure to coastal hazards.
#   - Financing gap for defense and retreat measures (funding shortfall as a percent of planned Phase 2/3 measures).
# - Hazard indicators
#   - Trend in sea-level rise (relative to local tide gauge data); trend in tropical cyclone severity and storm surge frequencies.
# - Social indicators
#   - Household displacement or relocation uptake rate; public acceptance and participation in relocation plans.
#   - Quality and speed of procurement, and number of complaints/appeals in a given period.
# - Governance indicators
#   - Timeliness of safeguards: procurement integrity checks, independent audits, and disclosure rates.
# - Thresholds for shifts (example, to be codified in a formal adaptive-management plan)
#   - Phase 1 → Phase 2: when 25–30% of urban population is exposed to credible flood risk within 10 years OR external financing commitments cover less than 50% of Phase 2 cost without compromising essential services; hazard maps finalized and governance body functioning.
#   - Phase 2 → Phase 3: when exposure reaches 40–50% of urban population OR defense/retreat cost share exceeds 60% of available financing windows OR a significant portion of heritage zones remains unprotected after Phase 2.
#   - Phase 3 → Phase 4: when 60–70% of high-risk coastline is secured or relocated, and a sustainable maintenance/financing plan exists with a functioning climate resilience fund.
#
# 4) Ethical trade-offs, equity, and protection of cultural heritage
# - Equity and inclusion
#   - Ensure the most vulnerable (low-income households, women-headed households, persons with disabilities, and residents of smaller islands) have prioritized access to relocation assistance, housing subsidies, and social protection.
#   - Create a Vulnerable Communities Advisory Panel with representation from all inhabited islands to guide benefit distribution, consent processes, and grievance redress.
# - Intergenerational justice
#   - Establish a Climate Adaptation Fund with long-term internal allocations and a clear capex-to-maintenance mix; ensure debt levels stay within debt-sustainability thresholds; set aside a portion of funds for future adaptation needs and disaster risk reduction.
# - Cultural heritage protection
#   - Preserve heritage through a dual strategy: (1) physical protections for at-risk sites where viable, and (2) cultural preservation via documentation, digitization, and community-driven stewardship; where relocation is unavoidable, ensure heritage is responsibly moved, memorialized, and continued in situ if possible (e.g., pilgrim paths, cultural practices, and storytelling).
# - Mechanisms to protect the most vulnerable
#   - Targeted subsidies and social protection; voluntary relocation options with generous, prompt, and transparent compensation; non-discrimination guarantees; culturally sensitive relocation planning that preserves social networks; community-managed livelihoods in new locations; ongoing health and education support for relocated families.
#
# 5) Financing plan: mix of domestic, concessional finance, climate funds, insurance, PPPs, and debt
# - Domestic revenue and public finance
#   - Create a resilient finance package: a modest resilience surcharge (e.g., on tourism-related services and property near coastlines) earmarked for adaptation, with exemptions for the lowest-income households; improve tax collection efficiency; reallocate existing budgets toward high-priority adaptation needs.
# - Concessional international finance and climate funds
#   - Target: grants and highly concessional loans from regional development banks (e.g., Asian Development Bank, World Bank, IDA-equivalents), and climate funds (Green Climate Fund, Global Environment Facility) for planning, early works, and risk-sharing facilities.
# - Insurance and risk transfer
#   - Develop a portfolio of risk transfer mechanisms: parametric insurance for public assets; catastrophe bonds once risk modeling matures; a sovereign disaster risk pool; micro-insurance products for households and small businesses.
# - Public–private partnerships (PPP) and private investment
#   - Use PPPs for hard infrastructure (defense works) with private operators for maintenance; environmental restoration projects co-financed with private philanthropies or impact investors; private sector co-financing in tourism diversification and resilient infrastructure.
# - Debt instruments
#   - Issue sovereign green bonds or climate resilience bonds with clear use-of-proceeds for defense and relocation programs; consider diaspora bonds to mobilize remittances from emigrant communities; guardrails on debt-to-GDP ratio and debt-service-to-revenue to avoid unsustainable leverage.
# - Conditionalities and fiscal implications
#   - Conditions: transparent procurement; independent project appraisals; social-impact assessments; open data and anti-corruption provisions; climate-risk-disclosure standards; transparent use of proceeds and regular independent audits.
#   - Fiscal implications: maintain a balanced approach with explicit caps on non-essential commitments; ensure debt service remains within sustainable levels; require performance-based disbursement and sunset clauses if milestones are not met; ensure refinancing options to mitigate rising interest rates.
# - Financing mix (illustrative)
#   - Domestic revenue and public finance: 25–35%
#   - Concessional finance and climate funds: 40–55%
#   - Insurance and risk transfer: 5–10%
#   - PPPs and private investment: 5–10%
#   - Diaspora and debt instruments (as feasible): 5–10%
# - Implementation note
#   - Start with Phase 1 costs primarily funded by the domestic adaptation budget, with early concessional financing secured for Phase 2 planning and initial works; build a framework that scales financing with demonstrated results and risk transfer readiness.
#
# 6) Governance, accountability, and anti-corruption safeguards
# - Institutions and decision-making
#   - Establish a National Climate Adaptation Council (N-CAC) chaired by the Prime Minister/President with cross-minister representation (planning, finance, environment, tourism, fisheries, housing, culture) and a rotating civil-society/municipal stakeholder seat.
#   - Create a dedicated Resilience Fund Management Office with fiduciary protections and independent annual audits; public dashboard with project-by-project budgets, timelines, and outcomes.
# - Procurement and transparency
#   - Require open bidding, third-party technical verification, and independent validation of risk assessments; publish tender documents, procurement awards, and contract performance against milestones.
# - Community engagement and consent
#   - Mandatory early engagement with communities; free, prior, informed consent processes, especially for relocations; local grievance redress mechanisms; participatory budgeting for a portion of resilience funds.
# - Monitoring, evaluation, and learning
#   - Quarterly progress reports, annual impact evaluations, and mid-course reviews; publish performance indicators in a public climate-resilience dashboard; adapt plans based on evidence and community feedback.
# - Safeguards against capture and misuse
#   - Independent anti-corruption unit with whistleblower protections; rotation of key project leadership; internal controls to prevent related-party transactions; annual external financial audits; sanctions for mismanagement.
# - Legal alignment
#   - Strengthen coastal zoning laws, land-tenure clarity, and safeguards for cultural heritage; ensure relocation laws include protections for customary rights, livelihoods, and access to essential services.
#
# 7) Three most important uncertainties and contingency measures
# - Uncertainty 1: Faster-than-expected sea-level rise or more intense storms
#   - Contingency: accelerate protection of additional coastline using flexible, modular defenses; scale up nature-based solutions; reserve budget lines for rapid procurement and authorized emergency expenditures; accelerate relocation of the most exposed communities if necessary.
# - Uncertainty 2: Abrupt economic shocks (global downturns affecting tourism or fish stocks)
#   - Contingency: strengthen economic diversification (ecotourism, culture-led experiences, value-added fisheries); create a resilience reserve and contingent financing arrangements; build local procurement and value chains to reduce external exposure; apply flexible debt-management strategies; heighten social protection and retraining programs.
# - Uncertainty 3: Migration pressures (internal crowding on safer islands or outward migration)
#   - Contingency: implement a proactive migration and diaspora policy that channels safe, voluntary movement with social protections and return options; invest in regional hubs and remote-living incentives; create *diaspora bonds* and targeted investments in communities hosting migrants; ensure cultural cohesion with inclusive decision processes and recognition of heritage in resettlement planning.
# - Additional contingencies
#   - If actual costs exceed projections, re-prioritize Phase 2/3 interventions toward the most cost-effective options; leverage more concessional financing or grant-based support; pause non-essential investments and refocus on essential services.
#
# 8) Defense against plausible critiques (succinct defenses)
# Critique 1: It’s fiscally irresponsible and undermines sovereignty by leaning too heavily on foreign financing and migration
# - Response
#   - The strategy uses a diversified financing mix, not dependence on foreign funds alone. It anchors a sovereign resilience fund, strict fiduciary controls, and transparent governance to control debt risk and ensure value for money. Foreign financing is used selectively for high-impact, high-need investments with clear concessional terms and milestones, reducing domestic fiscal pressures and enabling fast, large-scale risk reduction that would be impractical with domestic funds alone.
#   - Migration is voluntary, culturally sensitive, and policy-driven with explicit safeguards and local capacity-building. The diaspora strategy strengthens national resilience through remittances and knowledge transfer while maintaining the nation’s sovereignty and decision-making authority over relocation choices. The plan emphasizes local participation, affects distributional equity, and ensures no forced displacement.
#
# Critique 2: It is culturally destructive because it endorses relocation of heritage sites and communities
# - Response
#   - The blueprint prioritizes protection of heritage in situ where feasible, and uses relocation only when necessary to save lives and prevent systemic collapse. Even when relocation occurs, the design includes comprehensive preservation of culture—digital cataloging, community-led memory keeping, and re-creation of cultural practices in destination communities. Relocation is planned in a manner that respects customary rights, preserves social networks, and maintains long-term access to cultural knowledge. Where possible, heritage remains physically accessible via protective strategies and adaptive designs, with a strong emphasis on documentation and memory as a cultural asset.
#
# 9) Summary of expected outcomes
# - Within 10–15 years: substantial reduction in risk to urban cores and culturally significant zones; improved coast-wide risk management; diversified economy less exposed to climate shocks; a governed, transparent adaptation program with strong community buy-in.
# - By year 20: a resilient, participatory governance system with proven financing mechanisms, scaled protection for the coastline, a managed retreat option that minimizes disruption, and a stable infrastructure for ongoing adaptation, with cultural heritage protected through a combination of physical preservation and community-based stewardship.
#
# If you’d like, I can tailor this plan to your country’s exact coastline length, urban distribution, heritage site locations, and current fiscal indicators, and provide a more detailed budget break-down by sector with scenario analyses (low, medium, high climate risk).

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# # 20-Year Climate Adaptation Strategy for Low-Lying Island Nation
#
# ## Executive Summary
# This strategy balances protection of critical assets with pragmatic recognition that not everything can be defended. It prioritizes immediate risk reduction, builds adaptive capacity, and creates dignified pathways for those who must eventually relocate—while preserving cultural identity whether communities stay or go.
#
# ---
#
# ## PHASE 1: FOUNDATION & RISK REDUCTION (Years 1-5)
# **Budget: $750M ($150M/year)**
#
# ### Immediate Interventions
#
# #### 1.1 Comprehensive Risk Assessment & Early Warning ($25M)
# - **Timeline:** Months 1-12
# - **Activities:**
#   - High-resolution LiDAR mapping of all inhabited areas
#   - Household-level vulnerability assessments (physical, economic, social)
#   - Install real-time sea-level and storm monitoring network (15 stations)
#   - Community-based hazard mapping with traditional knowledge integration
# - **Benefits:** Evidence base for all decisions; reduced storm casualties
# - **Risks:** Data may increase anxiety; risk of information weaponization in political disputes
#
# #### 1.2 Critical Infrastructure Protection ($180M)
# - **Power and water systems hardening:** $80M
#   - Elevate generators, relocate water treatment inland, create redundancies
# - **Hospital and emergency services protection:** $60M
#   - Reinforce 3 regional hospitals, establish elevated emergency shelters (capacity 15,000)
# - **Port and airport resilience:** $40M
#   - Raise critical sections 1.5m, improve drainage
# - **Expected benefit:** Protect $800M in assets; maintain connectivity during crises
# - **Risks:** May create false sense of permanent security
#
# #### 1.3 Nature-Based Solutions Pilot Program ($120M)
# - **Mangrove restoration:** 500 hectares on 3 priority coastlines ($30M)
#   - 5-year maintenance contracts with local communities
#   - Expected 0.5-1m wave height reduction, fisheries habitat
# - **Coral reef restoration:** 3 priority sites ($25M)
#   - Coral gardening, artificial structures, marine protected areas
#   - Tourism revenue share to maintain community buy-in
# - **Coastal wetland rehabilitation:** 200 hectares ($20M)
# - **Beach nourishment and dune restoration:** 15km priority tourism/residential zones ($45M)
# - **Benefits:** 15-20 year protection for 40,000 people; ecosystem services $8M/year; local employment (350 jobs)
# - **Risks:** Climate stress may limit ecosystem recovery; requires sustained maintenance
#
# #### 1.4 Strategic Seawall Construction (Hard Infrastructure) ($200M)
# - **Protect 3 highest-priority areas only:**
#   - Capital city core and main port (8km): $120M
#   - Primary cultural heritage site (2km): $40M
#   - Secondary population center (4km): $40M
# - **Design:** Hybrid seawalls (3m height) with accessible public space, integrated drainage
# - **Expected lifespan:** 30-40 years with maintenance
# - **Benefits:** Direct protection for 85,000 people (34% population); preserve $1.2B assets
# - **Risks:** Costs 40% of Phase 1 budget; may induce development in protected zones; eventual overtopping; erosion of adjacent unprotected areas
#
# #### 1.5 Vulnerable Population Support ($85M)
# - **Housing elevation grants:** $50M
#   - Means-tested grants ($15,000-25,000 per household) for 2,500 lowest-income households in moderate-risk zones
#   - Technical assistance for elevation to 2m above current high tide
# - **Livelihood diversification fund:** $25M
#   - Retraining programs: aquaculture, renewable energy technicians, digital services, construction trades
#   - Small business grants for climate-resilient enterprises
#   - Target: 5,000 participants
# - **Community risk insurance pool:** $10M seed capital
#   - Subsidized parametric insurance for lowest income quartile
#   - Automatic payouts for named storms
# - **Benefits:** Immediate risk reduction for most vulnerable; builds human capital
# - **Risks:** Grants may create perverse incentives; moral hazard from insurance
#
# #### 1.6 Legal and Institutional Frameworks

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.0-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Okay, here's a prioritized, phased 20-year adaptation strategy tailored to the described low-lying island nation, addressing the core requirements and potential critiques.
#
# **Vision:** A resilient, equitable, and culturally vibrant island nation that proactively adapts to climate change, leveraging its strengths and fostering sustainable development.
#
# **Overarching Principles:**
#
# *   **Prioritization of Human Safety:** Protecting lives and livelihoods is paramount.
# *   **Equity and Inclusion:** Ensuring all citizens, particularly the most vulnerable, benefit from adaptation measures.
# *   **Community Ownership:** Engaging communities in decision-making and implementation.
# *   **Sustainability:** Promoting environmentally sound and economically viable solutions.
# *   **Transparency and Accountability:** Establishing robust governance structures and anti-corruption measures.
#
# **Phase 1: Building Resilience & Diversification (Years 1-5)**
#
# *   **Goal:** Enhance adaptive capacity, reduce immediate risks, and lay the groundwork for future transformations.
#
# | Intervention                               | Estimated Cost   | Timeline | Expected Benefits                                                              | Risks                                                                         |
# | :----------------------------------------- | :--------------- | :------- | :----------------------------------------------------------------------------- | :---------------------------------------------------------------------------- |
# | **Coastal Risk Assessment & Monitoring**    | $10M             | 1-2 yrs  | Improved understanding of coastal vulnerability; informed decision-making       | Inaccurate data; political interference in data interpretation                  |
# | **Ecosystem-Based Adaptation (EbA)**      | $30M             | 1-5 yrs  | Mangrove restoration, coral reef rehabilitation, dune stabilization; reduced wave action | Slow implementation; vulnerability of EbA to extreme events; limited scale |
# | **Early Warning Systems (EWS)**           | $5M              | 1-2 yrs  | Timely warnings for cyclones and storm surges; reduced loss of life             | System failure; lack of community awareness/response                           |
# | **Resilient Housing Program**              | $30M             | 2-5 yrs  | Retrofitting existing homes, incentivizing climate-resilient construction             | High construction costs; land tenure issues; difficulty in retrofitting        |
# | **Economic Diversification (Tourism)**    | $20M             | 1-5 yrs  | Promotion of eco-tourism, cultural tourism, and niche markets                       | Over-reliance on tourism; environmental damage; global economic downturn       |
# | **Economic Diversification (Fisheries)**  | $10M             | 1-5 yrs  | Sustainable fisheries management, aquaculture development, value-added processing    | Overfishing; disease outbreaks in aquaculture; market volatility             |
# | **Vocational Training**                    | $5M              | 1-5 yrs  | Skills development for new industries; improved employment opportunities        | Mismatch between training and labor market demand                              |
# | **Legal & Regulatory Reforms**             | $5M              | 1-3 yrs  | Land use planning, building codes, disaster risk reduction regulations              | Political opposition; weak enforcement                                         |
# | **Community Awareness & Education**       | $5M              | 1-5 yrs  | Public awareness campaigns, school curricula, training programs                     | Apathy; misinformation; difficulty in reaching remote communities            |
#
# **Quantitative Decision Thresholds & Indicators (Phase 1):**
#
# *   **Sea-level rise:** If sea-level rise exceeds the high-end projection (0.2m) after year 3, accelerate the resilient housing program and expand EbA efforts.
# *   **Storm intensity:** If annual average storm intensity (measured by the Saffir-Simpson scale) increases by one category from the baseline, review and strengthen EWS and evacuation plans.
# *   **Economic performance:** If tourism and fisheries sectors decline by more than 10% per year for two consecutive years, shift greater focus to economic diversification.
#
# **Phase 2: Proactive Adaptation & Strategic Retreat (Years 6-12)**
#
# *   **Goal:** Implement medium-term adaptation measures, including targeted coastal defenses and planned relocation in most vulnerable areas.
#
# | Intervention                               | Estimated Cost   | Timeline | Expected Benefits                                                                          | Risks                                                                                        |
# | :----------------------------------------- | :--------------- | :------- | :----------------------------------------------------------------------------------------- | :------------------------------------------------------------------------------------------- |
# | **Targeted Coastal Defenses**                | $50M             | 6-10 yrs | Protection of critical infrastructure (hospitals, power plants), towns, heritage sites    | High construction costs; limited effectiveness against extreme events; environmental impacts   |
# | **Managed Retreat & Resettlement Planning** | $20M             | 6-8 yrs  | Identification of safe relocation sites, development of relocation plans, community consultation | Social disruption; resistance to relocation; loss of cultural heritage                      |
# | **Resettlement Assistance Programs**        | $40M             | 8-12 yrs | Financial assistance for relocation, housing, job training; community support services      | Insufficient funding; social tensions between relocated and host communities               |
# | **Land Acquisition & Development**           | $30M             | 6-12 yrs | Purchase and development of land for resettlement, agriculture, and new industries      | Land scarcity; high land prices; environmental impacts of development                      |
# | **Diaspora Engagement**                     | $5M              | 6-12 yrs | Attracting investment, skills, and knowledge from the diaspora; facilitating remittances     | Brain drain; limited diaspora interest; potential for social tensions with host countries |
#
# **Quantitative Decision Thresholds & Indicators (Phase 2):**
#
# *   **Sea-level rise:** If sea-level rise exceeds 0.5m by year 10, accelerate managed retreat and limit further investment in hard coastal defenses.
# *   **Land loss:** If habitable land area decreases by more than 5% due to coastal erosion and inundation, expand land acquisition and resettlement efforts.
# *   **Community acceptance:** If community surveys indicate increasing resistance to relocation, revise relocation plans and enhance community engagement.
#
# **Phase 3: Long-Term Resilience & Sustainable Development (Years 13-20)**
#
# *   **Goal:** Secure long-term resilience through sustainable economic diversification, community empowerment, and international collaboration.
#
# | Intervention                               | Estimated Cost   | Timeline | Expected Benefits                                                                                  | Risks                                                                                              |
# | :----------------------------------------- | :--------------- | :------- | :------------------------------------------------------------------------------------------------- | :------------------------------------------------------------------------------------------------- |
# | **Sustainable Economic Diversification**    | $30M             | 13-20 yrs| Development of renewable energy, technology, education, and other non-climate-sensitive industries | Limited investment opportunities; lack of skilled labor; global economic competition                  |
# | **Education & Capacity Building**           | $10M             | 13-20 yrs| Investments in higher education, research, and development; promotion of innovation and entrepreneurship | Brain drain; lack of relevance to local needs; inadequate funding                                |
# | **International Collaboration**             | $5M              | 13-20 yrs| Building partnerships with other island nations, accessing international climate finance, promoting knowledge sharing | Dependence on external support; bureaucratic delays; political interference                             |
# | **Cultural Preservation**                  | $10M             | 13-20 yrs| Documentation and digitization of cultural heritage, creation of museums and cultural centers, support for cultural practices | Loss of intangible heritage; limited resources; lack of community engagement                              |
#
# **Quantitative Decision Thresholds & Indicators (Phase 3):**
#
# *   **GDP growth:** If GDP growth consistently lags behind regional averages, revise economic diversification strategies and attract foreign investment.
# *   **Employment rate:** If the unemployment rate exceeds 10%, strengthen vocational training and support for entrepreneurship.
# *   **Climate finance:** If access to international climate finance falls short of projected needs, explore alternative financing mechanisms.
#
# **Ethical Trade-offs & Mechanisms for Protecting the Most Vulnerable:**
#
# *   **Equity:**
#     *   Prioritize adaptation measures that benefit all citizens, particularly low-income communities and marginalized groups.
#     *   Ensure equitable access to resettlement assistance, housing, and employment opportunities.
#     *   Allocate resources based on vulnerability and need, rather than political influence.
# *   **Intergenerational Justice:**
#     *   Invest in sustainable development practices that protect the environment for future generations.
#     *   Promote climate-resilient infrastructure and housing.
#     *   Engage youth in adaptation planning and implementation.
# *   **Cultural Heritage:**
#     *   Document and digitize cultural heritage sites before relocation.
#     *   Relocate cultural artifacts and structures to safe locations.
#     *   Create new cultural centers and museums to preserve and promote cultural heritage.
#     *   Consult with communities on the relocation of cultural sites.
# *   **Protection of the Most Vulnerable:**
#     *   Provide targeted assistance to vulnerable groups, such as the elderly, disabled, and low-income families.
#     *   Ensure access to healthcare, education, and social services.
#     *   Develop social safety nets to protect against economic shocks.
#
# **Financing Plan:**
#
# *   **Domestic Revenue:** Increase tax revenues through economic diversification and improved tax collection.
# *   **Concessional International Finance:** Seek grants and low-interest loans from multilateral development banks and bilateral donors.
# *   **Climate Funds:** Access funding from the Green Climate Fund, Adaptation Fund, and other climate finance mechanisms.
# *   **Insurance:** Develop climate risk insurance schemes to protect against extreme weather events.
# *   **Public-Private Partnerships (PPPs):** Engage the private sector in financing and implementing adaptation projects.
# *   **Debt:** Use debt strategically to finance adaptation investments, but avoid unsustainable levels of debt.
#
# **Governance, Accountability, & Anti-Corruption Safeguards:**
#
# *   **Establish a National Climate Change Authority:** A cross-sectoral body responsible for coordinating adaptation planning and implementation.
# *   **Develop a National Adaptation Plan (NAP):** A comprehensive plan that outlines adaptation goals, strategies, and actions.
# *   **Implement transparent procurement processes:** Ensure fair and open competition for adaptation projects.
# *   **Strengthen anti-corruption laws and institutions:** Promote accountability and prevent corruption.
# *   **Establish community oversight mechanisms:** Engage communities in monitoring and evaluating adaptation projects.
# *   **Regular audits and evaluations:** Assess the effectiveness of adaptation measures and identify areas for improvement.
#
# **Key Uncertainties & Contingency Measures:**
#
# 1.  **Faster-than-expected Sea-Level Rise:**
#     *   **Contingency:** Accelerate managed retreat, invest in floating infrastructure, and explore the feasibility of creating artificial islands.
# 2.  **Abrupt Economic Shocks:**
#     *   **Contingency:** Diversify the economy further, establish a sovereign wealth fund, and strengthen social safety nets.
# 3.  **Migration Pressures:**
#     *   **Contingency:** Negotiate migration agreements with other countries, develop integration programs for migrants, and address the root causes of migration.
#
# **Defense Against Plausible Critiques:**
#
# 1.  **Critique: Fiscally Irresponsible & Undermines National Sovereignty**
#     *   **Defense:** This strategy is fiscally *responsible* because proactive adaptation is far cheaper than dealing with the consequences of inaction. While it relies on foreign financing, the strategy prioritizes domestic revenue generation through economic diversification, aiming for greater self-sufficiency over time. Dependence on foreign aid is viewed as a bridge to a more resilient and independent future, not a permanent state. Migration, while potentially a last resort, can also bring remittances and diaspora investment, strengthening the economy. The strategy respects national sovereignty by ensuring that all adaptation measures are aligned with national priorities and values, and implemented with the full participation of local communities.
# 2.  **Critique: Culturally Destructive**
#     *   **Defense:** This strategy acknowledges the immense importance of cultural heritage. Relocation is a *last resort*, considered only when the physical safety of heritage sites and communities is at extreme risk. Before any relocation, comprehensive documentation and digitization efforts will be undertaken. New cultural centers and museums will be established to preserve and promote cultural heritage. The process will involve extensive consultation with affected communities, ensuring that their values and traditions are respected. The goal is not to erase cultural heritage, but to safeguard it for future generations in a new, safe environment.
#
# This detailed strategy provides a roadmap for building a resilient and sustainable future for the island nation. It is flexible and adaptable, allowing for adjustments based on new information and changing circumstances. By prioritizing human safety, equity, community ownership, and sustainability, the strategy aims to create a brighter future for all citizens.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Of course. Here is a comprehensive 20-year adaptation strategy for the island nation, addressing all specified requirements.
#
# ***
#
# ### **A Resilient Future: A 20-Year Phased Adaptation Strategy for [Nation Name]**
#
# **Guiding Vision:** To navigate the climate crisis with foresight and justice, transforming vulnerability into resilience by protecting our people, diversifying our economy, and honoring our heritage through a blend of innovation, nature, and prudent stewardship.
#
# ---
#
# ### **1. Prioritized & Phased 20-Year Adaptation Strategy**
#
# This strategy is organized into three overlapping phases, designed to build foundational resilience, implement targeted protection, and enable transformative adaptation.
#
# #### **Phase 1: Foundational Resilience (Years 1-7)**
# *Focus:* Data, governance, no-regret actions, and protecting the most vulnerable.
#
# | Intervention | Description & Cost (Est. Total: $450M) | Timeline | Expected Benefits & Risks |
# | :--- | :--- | :--- | :--- |
# | **1. Coastal Vulnerability Atlas & Monitoring** | High-resolution mapping of erosion, flooding, and groundwater salinization. Real-time monitoring system. (**Cost: $30M**) | Years 1-3 | **Benefits:** Data-driven decisions, identifies most at-risk communities/assets. **Risks:** Data paralysis; must lead to action. |
# | **2. Strengthened Building Codes & Setbacks** | Legally mandate elevated, storm-resilient construction for all new builds. Establish a 50-meter coastal setback zone. (**Cost: $20M** for enforcement/tech assistance) | Years 1-5 (law by Y2) | **Benefits:** Reduces future risk and damages. **Risks:** Near-term political pushback from developers. |
# | **3. Mangrove & Coral Reef Restoration** | Nature-based solutions along 50% of vulnerable coasts. (**Cost: $100M**) | Years 2-10 | **Benefits:** Reduces wave energy, supports fisheries, sequesters carbon. **Risks:** Project failure; requires community stewardship. |
# | **4. Social Protection & Housing Voucher Scheme** | Targeted subsidies and vouchers for low-income households in high-risk zones for home elevation or relocation. (**Cost: $200M**) | Years 1-10 | **Benefits:** Protects most vulnerable, addresses equity. **Risks:** Perceived as unfair by those just above the threshold. |
# | **5. National Adaptation Trust Fund & Governance** | Establish a transparent, independent body to manage all adaptation finance. (**Cost: $5M** setup) | Year 1 | **Benefits:** Builds donor confidence, ensures accountability. **Risks:** Bureaucratic delays. |
# | **6. Economic Diversification Pilot: Aquaculture & IT** | Invest in salt-tolerant aquaculture and digital skills training. (**Cost: $95M**) | Years 3-7 | **Benefits:** Creates climate-resilient jobs, reduces tourism dependence. **Risks:** New markets may be difficult to penetrate. |
#
# #### **Phase 2: Targeted Protection & Managed Transition (Years 5-15)**
# *Focus:* Defending high-value areas, initiating planned relocation from untenable zones, and building new economic pillars.
#
# | Intervention | Description & Cost (Est. Total: $750M) | Timeline | Expected Benefits & Risks |
# | :--- | :--- | :--- | :--- |
# | **7. Hybrid Defenses for Critical Infrastructure** | Seawalls/reef balls integrated with mangroves to protect main port, airport, and 1-2 key economic zones. (**Cost: $300M**) | Years 5-12 | **Benefits:** Secures economic lifelines. **Risks:** High cost, can create false sense of security. |
# | **8. "Heritage & Habitat" Planned Relocation** | Voluntary, incentivized relocation of 3-5 most at-risk communities to pre-developed, elevated "climate-resilient neighborhoods." (**Cost: $300M**) | Years 6-15 | **Benefits:** Saves lives, reduces disaster response costs. **Risks:** Social disruption, loss of place-based cultural practices. |
# | **9. Digital Archiving of Cultural Sites** | Comprehensive 3D laser scanning and oral history projects for all major coastal heritage sites. (**Cost: $10M**) | Years 5-8 | **Benefits:** Preserves cultural memory even if sites are lost. **Risks:** Not a substitute for physical preservation. |
# | **10. National Health System Strengthening** | Bolster capacity for climate-related health issues (waterborne diseases, heat stress). (**Cost: $50M**) | Years 5-15 | **Benefits:** Protects human capital, a key asset. **Risks:** Underfunding in a constrained budget. |
# | **11. Diaspora Skills & Investment Platform** | Formalize links with emigrants for knowledge transfer, investment, and future migration pathways. (**Cost: $5M**) | Years 7-15 | **Benefits:** Taps into external resources and potential host countries. **Risks:** Can lead to "brain drain" if not managed. |
#
# #### **Phase 3: Transformative Adaptation (Years 10-20)**
# *Focus:* Scaling what works, making strategic decisions on long-term viability, and securing national legacy.
#
# | Intervention | Description & Cost (Est. Total: $600M+) | Timeline | Expected Benefits & Risks |
# | :--- | :--- | :--- | :--- |
# | **12. Decision on Major Heritage Sites** | Based on monitoring, decide to either: a) invest in permanent hard defenses, or b) conduct managed decommissioning and create a "Living Memorial." (**Cost: $150M-$400M**) | Decision by Y12 | **Benefits:** Clarity and a managed process for culturally sensitive sites. **Risks:** Profound cultural loss if relocation is chosen. |
# | **13. Scale Up Economic Diversification** | Major public-private partnerships in blue economy (sustainable marine biotech) and remote IT services. (**Cost: $200M**) | Years 10-20 | **Benefits:** Creates a sovereign wealth fund for future needs. **Risks:** High initial investment with uncertain returns. |
# | **14. Bilateral Labor & Migration Agreements** | Negotiate agreements with 2-3 partner nations for preferential migration and workforce integration. | Years 10-20 | **Benefits:** Provides a safety valve and future opportunities for citizens. **Risks:** Political resistance on sovereignty grounds. |
#
# ---
#
# ### **2. Quantitative Decision Thresholds & Triggers**
#
# *   **Trigger to Accelerate Managed Retreat (from Phase 2):**
#     *   **Coastal Erosion:** >5 meters of shoreline loss per year, sustained over 3 years, in a populated area.
#     *   **Flooding Frequency:** A key community experiences >3 severe (≥0.5m) tidal or storm floods per year.
#     *   **Groundwater:** Salinization of the primary freshwater lens extends to >40% of its area.
# *   **Trigger to Invest in Hard Coastal Defenses:**
#     *   An economic viability assessment shows that the Net Present Value of protecting a specific economic zone (e.g., main port) over 30 years exceeds the cost of defense by a factor of 3:1.
# *   **Trigger to Scale Up Diaspora/Migration Policy (to Phase 3):**
#     *   The annual adaptation budget exceeds 15% of GDP, indicating fiscal stress and the need for a more fundamental population-resource balance strategy.
#
# ---
#
# ### **3. Ethical Trade-offs & Protection of the Vulnerable**
#
# *   **Equity:** The **Housing Voucher Scheme (Intervention #4)** directly addresses socio-economic equity by targeting resources to those who cannot afford to adapt. The "climate-resilient neighborhoods" in the relocation program will include mixed-income housing to prevent the creation of poverty enclaves.
# *   **Intergenerational Justice:** Investing in **nature-based solutions (#3)** and **economic diversification (#6, #13)** provides long-term benefits (healthy ecosystems, future jobs) rather than consuming the entire budget on short-term hard defenses that may be obsolete in 50 years.
# *   **Cultural Heritage:** The strategy adopts a tiered approach: **1. Protect in place** where feasible and cost-effective (hybrid defenses for key sites), **2. Adapt use** (e.g., elevating structures), and **3. Document and memorialize** when physical preservation becomes impossible (#9, #12). This ensures the nation's story is never lost, even if specific locations are.
#
# ---
#
# ### **4. Realistic Financing Plan (Total: ~$1.8B over 20 years)**
#
# | Source | Amount (Est.) | Conditionality & Fiscal Implications |
# | :--- | :--- | :--- |
# | **Domestic Revenue** | $450M (25%) | From a modest "Climate Resilience Levy" on tourism (1-2% on hotel stays/tours). Implies political will to self-fund. |
# | **Concessional International Finance** | $720M (40%) | Loans/grants from multilateral development banks (World Bank, ADB). Requires strong governance (#5) and feasibility studies. Adds to public debt but at low rates. |
# | **International Climate Funds** | $450M (25%) | Grants from Green Climate Fund, Adaptation Fund. Highly competitive; requires demonstrating vulnerability and co-benefits (e.g., gender, biodiversity from #3). |
# | **Public-Private Partnerships (PPPs)** | $180M (10%) | Primarily for economic diversification projects (#13) and potentially resilient infrastructure. Risk of private partner prioritizing profit over public good. |
# | **Insurance & Catastrophe Bonds** | - | Sovereign parametric insurance to cover post-disaster response, protecting the core budget. Premiums are an annual cost. |
#
# ---
#
# ### **5. Governance & Anti-Corruption Safeguards**
#
# *   **National Adaptation Trust Fund (Intervention #5):** Managed by an independent board including govt., opposition, civil society, and diaspora reps. All projects and disbursements are publicly audited and published online.
# *   **Community-Led Adaptation Committees:** Established on each island to prioritize local projects and monitor implementation, ensuring bottom-up input and buy-in.
# *   **Anti-Corruption Protocols:** Mandatory open bidding for all contracts >$100,000; integrity pacts signed by all bidders; and a dedicated, public whistleblower channel with legal protections.
#
# ---
#
# ### **6. Key Uncertainties & Contingency Measures**
#
# 1.  **Uncertainty: Faster-than-Expected Sea-Level Rise** (e.g., >1.5m by 2070).
#     *   **Contingency:** The decision thresholds for **managed retreat (#8)** would be automatically triggered earlier. The strategy would compress Phases 2 and 3, reallocating funds from long-term defenses (#7) towards accelerated relocation and migration planning (#14).
# 2.  **Uncertainty: Abrupt Economic Shock** (e.g., global pandemic cratering tourism).
#     *   **Contingency:** Activate sovereign insurance. Implement a temporary pause on large capital projects (#7) and shift focus to labor-intensive nature-based solutions (#3) and digital archiving (#9) to provide employment.
# 3.  **Uncertainty: Sudden Mass Migration Pressure** from a neighboring, less-resilient state.
#     *   **Contingency:** Leverage nascent **diaspora agreements (#11, #14)** to seek international support and burden-sharing from regional partners and the UN, framing it as a regional climate security issue.
#
# ---
#
# ### **Defense Against Critiques**
#
# **Critique 1: "This strategy is fiscally irresponsible and undermines national sovereignty by relying too much on foreign financing and migration."**
#
# *   **On Fiscal Irresponsibility:** A "do nothing" approach is the true fiscal irresponsibility. The cost of a single major cyclone without these measures could wipe out a year's GDP. This plan is an investment that protects our primary economic assets (tourism, infrastructure) and builds new ones. It uses limited domestic funds to catalyze much larger international grants and concessional finance, which is a fiscally prudent leveraging of our resources.
# *   **On Sovereignty:** Sovereignty is not just control over territory; it is the ability to secure a future for our people. By strategically engaging with international finance and migration pathways, we are exercising our sovereignty to secure the best possible outcome for our citizens. We are not ceding control; we are proactively building partnerships to manage a crisis we did not create. The robust governance safeguards ensure we, not foreign donors, remain in the driver's seat.
#
# **Critique 2: "This strategy is culturally destructive because it endorses relocation of heritage sites and communities."**
#
# *   This critique misunderstands the strategy's profound respect for our culture. Our culture does not reside solely in stones and places; it lives in our people, our stories, and our traditions. The strategy prioritizes **protecting heritage in place where physically and financially feasible**. However, when faced with the certain loss of a site to the sea, a managed process of **digital archiving (#9)** and creating a **"Living Memorial" (#12)** is an act of preservation, not destruction. It is the only way to ensure our grandchildren know who they are and where they come from. Allowing a site to be destroyed by inaction is the truly culturally destructive path. The community-led process ensures that the spirit of these places is honored and carried forward.

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ## 1.  Executive Summary
#
# **Goal:** Keep the nation habitable, productive and culturally intact while limiting cumulative adaptation cost to **≈ US $1.5 bn** over 20 years (US $150 m / yr).
#
# **Approach:** A **four‑phase, trigger‑based** plan that mixes **hard protection**, **nature‑based solutions (NbS)**, **managed retreat**, **housing & land‑use reforms**, **economic diversification**, and **legal/ migration policies**.
#
# | Phase | Years | Core Logic | Primary Budget Share |
# |------|------|------------|----------------------|
# | **1 – “Secure & Diagnose”** | 0‑5 | Immediate risk reduction, data & governance foundations | 35 % (US $525 m) |
# | **2 – “Resist & Relocate”** | 5‑10 | Scale up defenses where cost‑effective; begin voluntary retreat of the most exposed | 30 % (US $450 m) |
# | **3 – “Transform & Diversify”** | 10‑15 | Shift economic base, cement long‑term land‑use, deepen NbS | 20 % (US $300 m) |
# | **4 – “Consolidate & Exit”** | 15‑20 | Complete retreat of high‑risk zones, secure heritage in “safe‑havens”, final financing closure | 15 % (US $225 m) |
#
# A **decision‑threshold matrix** (Section 2) tells the government when to accelerate retreat, pause new hard works, or re‑allocate funds.
#
# ---
#
# ## 2.  Quantitative Decision Thresholds & Phase‑Switch Triggers
#
# | Indicator (nationally averaged) | Trigger for **Phase‑Shift** | Action |
# |---------------------------------|-----------------------------|--------|
# | **Sea‑level rise (SLR) relative to 2025 baseline** | **> 0.55 m** (by Year 10) or **> 0.80 m** (by Year 15) | Shift from Phase 2 → Phase 3: halt new seawalls >10 km from shore, prioritize retreat. |
# | **Average annual coastal erosion rate** | **> 0.6 m yr⁻¹** over 3 consecutive years | Accelerate managed retreat in affected districts; pause further hard defenses in that stretch. |
# | **Economic loss from storm events** | **> 3 % of GDP** in a single year or **> 10 % cumulative** over 5 years | Trigger emergency fund (see financing) and fast‑track relocation of affected households. |
# | **Housing vulnerability index** (share of population living in “high‑risk” dwellings) | **> 30 %** of total pop. | Activate mandatory retro‑fit programme and increase voluntary buy‑out budget. |
# | **Cultural‑site exposure score** (combined SLR + erosion + storm surge) | **≥ 0.7** (scale 0‑1) for any UNESCO‑listed site | Immediate emergency protection (e.g., temporary flood barriers) and fast‑track digitisation/relocation plan. |
#
# **Monitoring Cadence:**
# - **Annual technical review** (hydro‑meteorology, GIS erosion maps).
# - **Bi‑annual socio‑economic survey** (housing, livelihood, migration intentions).
# - **Quarterly steering‑committee update** to decide whether a trigger has been crossed.
#
# ---
#
# ## 3.  Phased 20‑Year Adaptation Portfolio
#
# ### Phase 1 – “Secure & Diagnose” (Years 0‑5)
#
# | # | Intervention | Description & Scope | Cost (US $ m) | Timeline | Expected Benefits* | Main Risks |
# |---|--------------|----------------------|----------------|----------|-------------------|------------|
# | 1 | **Integrated Coastal Risk Mapping** | High‑resolution LiDAR, satellite altimetry, community‑based hazard surveys (all 12 islands). | 12 | 0‑2 | Baseline for every later decision; improves insurance underwriting. | Data gaps, skill retention. |
# | 2 | **Early‑warning & Emergency Response System** | Siren network, SMS alert platform, 20‑person rapid‑response teams per island. | 18 | 0‑3 | Reduces storm‑mortality by >40 %; protects tourism assets. | Maintenance, false‑alarm fatigue. |
# | 3 | **Pilot NbS – Mangrove & Seagrass Restoration** | 3 km of mangroves (East island) + 5 km² seagrass (lagoon). | 15 | 0‑4 | 0.3 m of wave attenuation, carbon sink, fish‑nursery (+5 % catch). | Land‑use conflicts, slow growth. |
# | 4 | **Critical‑Infrastructure Hardening** | Elevate 5 key tourism resorts, 2 main fish‑processing plants, and the main port (raise +2 m, flood‑gates). | 45 | 1‑5 | Keeps 30 % of GDP functional after +1 m SLR event. | High CAPEX, limited lifespan. |
# | 5 | **Legal & Institutional Reforms** | Enact *Coastal Zone Management Act* (CZMA), create *National Adaptation Council (NAC)*, revise zoning to 10‑m setback. | 4 | 0‑2 | Provides clear authority, reduces ad‑hoc building. | Political push‑back. |
# | 6 | **Community‑Based Relocation Fund (Voluntary Buy‑Out Pilot)** | 200 households in the most exposed village (Island A) offered market‑price land swaps + cash grant. | 10 | 2‑5 | Tests social acceptability, generates early “safe‑haven” settlement model. | Perceived inequity if later expanded. |
# | 7 | **Tourism & Fisheries Diversification Grant** | Seed‑fund for 30 eco‑tourism operators (inland trails, cultural museums) & 15 aquaculture pilots (sea‑cage, land‑based). | 36 | 1‑5 | Reduces dependence on shoreline assets; creates 800 jobs. | Market acceptance. |
#
# \*Benefits expressed in avoided damages, GHG sequestration, or job creation; quantified where possible (e.g., 0.3 m wave attenuation ≈ US $10 m/yr avoided damage).
#
# **Total Phase 1 outlay:** **US $140 m** (≈ 93 % of the 5‑year budget, leaving a modest contingency).
#
# ---
#
# ### Phase 2 – “Resist & Relocate” (Years 5‑10)
#
# | # | Intervention | Scope | Cost (US $ m) | Timeline | Benefits | Risks |
# |---|--------------|-------|----------------|----------|----------|------|
# | 1 | **Scale‑up NbS** – 12 km mangrove, 15 km² seagrass, 8 km dune re‑planting | Across all islands, prioritising tourism corridors. | 30 | 5‑9 | Cumulative wave attenuation 0.8 m, carbon capture 0.5 Mt CO₂e/yr. | Land‑use, maintenance. |
# | 2 | **Selective Seawall & Flood‑Gate Network** | 20 km of “strategic” hard barriers protecting the central business district and the heritage zone of Island B (cost‑effectiveness threshold ≤ US $4 m / km). | 60 | 5‑9 | Secures 15 % of GDP, protects UNESCO‑listed temple. | High maintenance, may induce downstream erosion. |
# | 3 | **Managed Retreat – “Safe‑Haven” Development** | 3 new planned towns on higher interior ridges (total 12 km²) with schools, health centre, and market. | 40 | 6‑10 | Relocates 12 % of at‑risk pop., reduces future relocation cost by 40 %. | Social cohesion, land‑rights disputes. |
# | 4 | **National Housing Retrofit Programme** | Subsidised elevation + flood‑proofing for 5 000 existing dwellings (incl. low‑income). | 20 | 5‑10 | Lowers household vulnerability index from 0.38 → 0.22. | Funding leakage, quality control. |
# | 5 | **Diaspora Engagement & “Return‑Bond” Scheme** | Issue $30 m diaspora bonds (10‑year, 2 % coupon) to finance safe‑haven infrastructure; tie to conditional “return‑to‑work” incentives. | 30 (bond proceeds) | 5‑7 (issuance) | Mobilises external capital, preserves national ownership. | Currency risk, need for robust legal framework. |
# | 6 | **Insurance Pool – “Island Resilience Fund”** | Co‑pay with regional reinsurers; premium subsidies for tourism operators and fishers. | 10 (seed) | 5‑8 | Provides rapid post‑storm liquidity; limits fiscal shock. | Moral hazard, premium escalation. |
#
# **Total Phase 2 outlay:** **US $190 m** (exceeds the nominal $150 m/yr budget – financed by the Phase 1 surplus, diaspora bonds, and a $30 m concessional loan from the Green Climate Fund).
#
# ---
#
# ### Phase 3 – “Transform & Diversify” (Years 10‑15)
#
# | # | Intervention | Scope | Cost (US $ m) | Timeline | Benefits | Risks |
# |---|--------------|-------|----------------|----------|----------|------|
# | 1 | **Full Economic Diversification Strategy** | Create a “Blue‑Economy” hub (research institute, sustainable aquaculture, renewable energy) – 5 MW solar‑wind hybrid, 10 MW offshore wind pilot. | 70 | 10‑14 | Generates US $200 m/yr new GDP by 2035; reduces fishing pressure. | Capital intensity, skill gap. |
# | 2 | **Legal Reform – “Climate‑Migration Act”** | Codify rights of internally displaced persons (IDPs), streamline land‑swap procedures, guarantee compensation. | 5 | 10‑12 | Provides security for relocation; reduces social unrest. | Implementation capacity. |
# | 3 | **Cultural Heritage Preservation & “Living Museum”** | Relocate at‑risk heritage structures to the new safe‑haven towns using “structural relocation” (e.g., UNESCO‑approved methods). Digitise 100 % of artefacts. | 45 | 11‑15 | Safeguards identity; tourism‑friendly heritage corridor. | High upfront cost, possible loss of context. |
# | 4 | **Education & Skills Transition Programme** | 2 000 scholarships for marine‑science, renewable‑energy, hospitality management; community‑based training. | 20 | 10‑15 | Increases labour‑market adaptability; supports new sectors. | Retention of graduates. |
# | 5 | **Adaptive Land‑Use Planning Tool (GIS‑based)** | Real‑time SLR projection overlay for permitting; public portal. | 8 | 10‑12 | Transparent decision‑making; reduces illegal coastal build‑up. | Requires continual data updates. |
#
# **Total Phase 3 outlay:** **US $148 m** (well within $150 m/yr).
#
# ---
#
# ### Phase 4 – “Consolidate & Exit” (Years 15‑20)
#
# | # | Intervention | Scope | Cost (US $ m) | Timeline | Benefits | Risks |
# |---|--------------|-------|----------------|----------|----------|------|
# | 1 | **Final De‑Commissioning of Uneconomic Hard Defenses** | Remove/repurpose 12 km of seawall that no longer meets cost‑effectiveness threshold. | 12 | 15‑17 | Re‑allocates maintenance funds, restores natural coastline. | Short‑term exposure during removal. |
# | 2 | **Complete Relocation of Remaining High‑Risk Communities** | 8 000 residents (≈ 3 % of pop.) moved to safe‑haven towns; cash‑plus‑land assistance. | 35 | 16‑20 | Ends new exposure; prevents future emergency evacuations. | Social integration challenges. |
# | 3 | **Long‑Term Climate‑Resilience Sovereign Bond** | Issue $200 m 30‑year green bond (interest linked to SLR performance) to refinance remaining debt and fund maintenance. | 200 (proceeds) | 18‑20 | Locks in low‑cost financing; signals fiscal responsibility. | Market appetite must be managed. |
# | 4 | **Monitoring & Evaluation (M&E) Institutionalisation** | Independent audit unit, annual public “Adaptation Report Card”. | 5 | 15‑20 | Ensures accountability, informs future policy. | Needs skilled auditors. |
# | 5 | **Diaspora & Return‑Migration Incentive Scheme** | Tax credits, land‑lease priority for diaspora families who return and invest in safe‑haven enterprises. | 10 (budget) | 17‑20 | Reinforces national identity, attracts capital. | Requires clear eligibility rules. |
#
# **Total Phase 4 outlay:** **US $262 m** (mostly financed by bond proceeds, insurance payouts, and residual climate‑fund allocations).
#
# ---
#
# ## 4.  Ethical Trade‑off Balancing
#
# | Ethical Dimension | How It is Addressed | Concrete Safeguards |
# |-------------------|---------------------|---------------------|
# | **Equity (socio‑economic groups & islands)** | • **Progressive funding formula** – islands with > 30 % high‑risk housing receive 1.5 × per‑capita share of relocation budget.<br>• **Targeted subsidies** for low‑income households (retrofit grants, cash‑plus‑land). | • Community‑level oversight committees (one per island) with gender‑balanced representation.<br>• Transparent beneficiary registers, audited quarterly. |
# | **Intergenerational Justice** | • **Discounted‑cash‑flow analysis** uses a **2 % social discount rate** (lower than typical market rates) to justify upfront investment versus future losses.<br>• **Carbon‑sequestration NbS** provide climate mitigation benefits for future generations. | • Legal “Future‑Generation Trust” (US $10 m) locked in the national budget to fund any unforeseen SLR beyond 1 m. |
# | **Cultural Heritage** | • **“In‑situ first” principle** – all hard defenses are first evaluated for their ability to protect heritage sites without relocation.<br>• When relocation is unavoidable, **“cultural continuity packages”** (transport of community leaders, recreation of ceremonial spaces, digital archiving) are mandatory. | • UNESCO‑advisory panel involvement; independent heritage impact assessment before any major works. |
# | **Sovereignty & Ownership** | • **Domestic lead agency (NAC)** retains decision‑making; all foreign financing contracts require **national‑interest clauses** (e.g., no conditional policy changes).<br>• **Diaspora bonds** are issued under domestic law, not external debt. | • Parliamentary ratification of each financing agreement; public hearings before signing. |
#
# ---
#
# ## 5.  Realistic Financing Mix
#
# | Source | Share of Total (US $ 1.5 bn) | Instruments / Conditions | Fiscal Implications |
# |--------|----------------------------|--------------------------|---------------------|
# | **Domestic Revenue** (general tax, tourism levy) | 30 % (US $450 m) | • 2 % tourism occupancy tax earmarked for adaptation.<br>• Progressive property tax on high‑value coastal assets. | Increases annual fiscal pressure by **≈ 0.7 % of GDP** (manageable under current deficit rules). |
# | **Concessional International Finance** (Green Climate Fund, Adaptation Fund, World Bank) | 25 % (US $375 m) | • Grants for NbS, capacity building.<br>• Low‑interest ($0.2 %/yr) loans for hard infrastructure.<br>**Conditionality:** robust M&E, stakeholder participation. | Minimal debt impact; requires compliance reporting. |
# | **Climate‑Risk Insurance & Catastrophe Bonds** | 15 % (US $225 m) | • Parametric flood/ storm surge cover (payout triggered at > 0.5 m surge).<br>• Reinsurance pool with Caribbean Catastrophe Risk Insurance Facility (CCRIF). | Premiums funded from tourism levy; reduces fiscal shock after events. |
# | **Public–Private Partnerships (PPP)** | 10 % (US $150 m) | • Build‑Operate‑Transfer (BOT) for solar‑wind hub.<br>• Private‑sector design‑build of selective seawalls (maintenance fee). | Revenue‑sharing contracts; risk transfer for operation/maintenance. |
# | **Diaspora Bonds & “Return‑Bond”** | 10 % (US $150 m) | • 10‑year sovereign green bond, 2 % coupon, guaranteed by national sovereign rating.<br>• Bond proceeds locked for safe‑haven development. | Debt‑service cost modest; bonds can be refinanced later at lower rates. |
# | **Contingency / Reserve Fund** | 10 % (US $150 m) | • Set‑aside for unexpected SLR spikes or economic shocks.<br>• Managed by independent fiduciary board. | Enhances resilience; not counted as regular spending. |
#
# **Debt‑Sustainability Test:**
# - **Debt‑to‑GDP** after 20 years (assuming $200 m new debt from concessional loans & bonds): **≈ 45 %** (still below the 60 % threshold used by most multilateral lenders).
# - **Debt service** ≈ **US $8 m/yr**, i.e., **0.27 % of GDP**, well within fiscal space.
#
# ---
#
# ## 6.  Governance, Accountability & Anti‑Corruption Safeguards
#
# 1. **National Adaptation Council (NAC)** – chaired by the Prime Minister, includes ministries, opposition leader, civil‑society reps, indigenous community heads, and diaspora liaison.
# 2. **Sectoral Working Groups** (Coastal Protection, Housing, Heritage, Finance) – develop detailed work‑plans, submit quarterly progress reports.
# 3. **Public Transparency Portal** – real‑time budget execution, contract awards, GIS‑maps of relocation zones; open data for journalists and NGOs.
# 4. **Independent Audit Office (IAO)** – annual audit of all adaptation funds; findings presented to Parliament and published online.
# 5. **Whistle‑blower Protection Law** – confidential reporting channel, legal immunity for reporters of misuse.
# 6. **Community Benefit Agreements (CBAs)** – any PPP contract must include a CBA guaranteeing local employment, training, and profit‑sharing.
# 7. **Performance‑Based Disbursement** – tranche release tied to pre‑agreed milestones (e.g., % of mangrove survival after 2 years).
#
# **Result:** A clear chain of responsibility, incentives for performance, and multiple layers of external oversight.
#
# ---
#
# ## 7.  Three Critical Uncertainties & Contingency Measures
#
# | Uncertainty | Potential Impact | Contingency Strategy |
# |-------------|------------------|----------------------|
# | **A. Faster‑than‑expected Sea‑Level Rise (≥ 1.2 m by 2050)** | Hard defenses become uneconomic; many more people forced to relocate; tourism assets lost. | • **Pre‑approved “Rapid‑Retreat Protocol”** – unlock the Contingency Fund (US $150 m) to purchase land and build additional safe‑haven towns.<br>• **Adaptive Design Clause** in all new infrastructure (e.g., foundations that can be lifted). |
# | **B. Abrupt Global Economic Shock (tourism demand drops 30 % for > 5 years)** | Revenue shortfall for adaptation levy; higher debt‑service risk. | • **Fiscal Buffer** – retain 5 % of GDP in a sovereign wealth‑style stabilization fund (seeded from early‑year tourism levy).<br>• **Diversify export base** – fast‑track aquaculture and renewable‑energy export contracts to regional markets. |
# | **C. Large‑Scale Migration Pressure (both inbound diaspora return and outbound climate migration)** | Housing market stress; cultural integration challenges; possible brain‑drain. | • **Dynamic Migration Management Plan** – tiered visa system offering preferential residency to skilled diaspora willing to invest in safe‑haven enterprises.<br>• **Social Cohesion Program** – community dialogue, cultural festivals, and school curricula emphasizing shared heritage. |
#
# Each contingency includes **trigger thresholds** (see Section 2) and **pre‑negotiated financing lines** (e.g., standby credit from the Caribbean Development Bank).
#
# ---
#
# ## 8.  Defending the Strategy
#
# ### Critique 1 – *“It is fiscally irresponsible and undermines sovereignty by relying too much on foreign financing and migration.”*
#
# **Response:**
#
# | Point | Evidence |
# |-------|----------|
# | **Fiscal Discipline** | Total debt after 20 years stays **< 45 % of GDP**; debt service < 0.3 % of GDP. The bulk (≈ 60 %) of financing is **domestic** (taxes, tourism levy) and **concessional** (grant‑heavy) – not market‑rate foreign borrowing. |
# | **Sovereign Control** | All foreign contracts contain **national‑interest clauses**; the NAC – a domestic, multi‑party body – retains final decision power. Diaspora bonds are issued under national law, not under external lender terms. |
# | **Strategic Use of Migration** | The “return‑bond” and “diaspora bond” are **financial instruments**, not surrender of policy space. They channel diaspora capital **back to the nation** while preserving the right to regulate immigration. |
# | **Risk Transfer, Not Dumping** | Insurance and catastrophe bonds **protect** the national budget from climate shocks, preserving fiscal space rather than creating dependence. |
#
# Thus, the financing plan **leverages low‑cost external resources** while keeping **policy sovereignty intact** and **maintaining debt sustainability**.
#
# ### Critique 2 – *“It is culturally destructive because it endorses relocation of heritage sites and communities.”*
#
# **Response:**
#
# | Aspect | How the Plan Protects Culture |
# |--------|------------------------------|
# | **“In‑situ First” Rule** | Every hard‑defence project is evaluated for its capacity to *preserve* heritage on its original site. Only when the cost‑benefit ratio (> US $6 m / ha) exceeds a strict threshold is relocation considered. |
# | **Heritage‑Continuity Packages** | Relocation includes **full reconstruction of ceremonial spaces**, **transfer of community leadership**, and **digital archiving** (3‑D scans, VR tours) – ensuring that cultural meaning travels with the people. |
# | **International Heritage Oversight** | UNESCO and ICOMOS are mandated as independent reviewers of any move; their sign‑off is required before any demolition or relocation. |
# | **Community‑Led Decision‑Making** | Relocation is **voluntary** and compensated at **market‑plus‑cultural‑value** rates; the community decides the design of the new settlement (layout, naming, monuments). |
# | **Economic Substitution** | Diversification into eco‑tourism and cultural‑heritage museums in safe‑haven towns **creates new venues** for heritage expression, turning a risk into an opportunity. |
#
# Hence, relocation is **not a cultural erasure** but a **managed cultural continuity** that safeguards both tangible and intangible heritage for future generations.
#
# ---
#
# ## 9.  Bottom Line
#
# - **Phase‑wise, data‑driven** actions keep the nation habitable while respecting equity and heritage.
# - **Triggers** ensure the plan can pivot quickly if sea level, storms, or economics move faster than expected.
# - **Financing** blends domestic resources, low‑cost concessional aid, innovative diaspora bonds, and risk‑transfer instruments, keeping debt sustainable and sovereignty intact.
# - **Governance** mechanisms (NAC, CBAs, transparency portal, audits) safeguard against corruption and guarantee community buy‑in.
#
# Adopting this roadmap gives the nation a **clear, financially viable, and ethically balanced path** to survive the next 20 years of climate change while preserving its people, economy, and cultural soul.

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
