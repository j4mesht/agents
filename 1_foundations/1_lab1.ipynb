# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A bat and a ball cost $1.10 in total. The bat costs $1.00 more than the ball. How much does the ball cost?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's denote:
#
# - Cost of the ball = \( x \) dollars
# - Cost of the bat = \( x + 1.00 \) dollars (since the bat costs $1.00 more)
#
# The total cost is:
#
# \[
# x + (x + 1.00) = 1.10
# \]
#
# Simplify:
#
# \[
# 2x + 1.00 = 1.10
# \]
#
# Subtract 1.00 from both sides:
#
# \[
# 2x = 0.10
# \]
#
# Divide both sides by 2:
#
# \[
# x = 0.05
# \]
#
# **Answer: The ball costs 5 cents.**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's denote:
#
# - Cost of the ball = \( x \) dollars
# - Cost of the bat = \( x + 1.00 \) dollars (since the bat costs $1.00 more)
#
# The total cost is:
#
# \[
# x + (x + 1.00) = 1.10
# \]
#
# Simplify:
#
# \[
# 2x + 1.00 = 1.10
# \]
#
# Subtract 1.00 from both sides:
#
# \[
# 2x = 0.10
# \]
#
# Divide both sides by 2:
#
# \[
# x = 0.05
# \]
#
# **Answer: The ball costs 5 cents.**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an agentic ai oppportunity."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-5",
    messages=messages

)

# Then read the business idea:

business_idea = response.choices[0].message.content
print("Business Area: ", business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# Business Area:  Business area: B2B accounts receivable and vendor-portal operations automation
#
# Why it’s a strong agentic AI fit
# - High-friction, multi-step workflows across emails, EDI, PDFs, and 100+ customer portals (Ariba, Coupa, Taulia, SAP Business Network, iSupplier, Tungsten, Retail Link, etc.)
# - Clear ROI: faster cash collection, fewer short-pays/chargebacks, reduced manual hours
# - Repetitive exception handling that benefits from persistence, context, and tool use (browser, email, phone, EDI)
#
# Core problem
# - Mid-market suppliers selling to enterprises get paid through buyer portals with strict rules. Small submission errors, missing docs (PO, BOL, POD, COA), or ASN mismatches lead to rejections, short-pays, and long DSO. Teams spend countless hours logging into portals, fixing fields, uploading documents, following up with AP, and reconciling remittances.
#
# Agentic solution (what the agent actually does)
# - Monitors open invoices in ERP and payer portals; tracks state from “submitted” to “paid”
# - Submits invoices to the correct channel (portal/EDI/email) and fixes rejections
# - Logs into portals to check status, retrieve remittances, and upload missing docs
# - Resolves exceptions: PO mismatch, missing GRN/receipt, ASN mismatch, duplicate invoice flag
# - Disputes short-pays/chargebacks with evidence (POD, delivery signatures, contracts)
# - Emails/calls AP or opens portal tickets; schedules callbacks and calendar holds
# - Reconciles payments and remittances back to ERP, closes out items, and escalates edge cases with a concise brief
#
# Who buys it
# - Mid-market suppliers in CPG, industrials, manufacturing, food & bev, packaging, and 3PLs with 10–100+ enterprise customers using portals
# - Titles: Controller, AR Manager, VP Finance/Operations, Shared Services leads
#
# Integrations and tools
# - ERP/accounting: NetSuite, QBO, Sage Intacct, SAP B1, Microsoft Dynamics
# - EDI: 850/855/856/810 flows via SPS, TrueCommerce, DiCentral, Boomi
# - Portals: Ariba, Coupa, Taulia, Tungsten, SAP BN, iSupplier, Retail Link (start with 3–5)
# - Email/phone: Gmail/Office 365; voice agent for AP follow-ups
# - Document parsing: BOL/POD/remittance PDF extraction; contract/SLA lookup (RAG)
#
# Key metrics
# - DSO reduction and cash acceleration
# - Touchless rate: invoices paid without human touch
# - Exception resolution time and first-pass acceptance rate
# - Short-pay/chargeback recovery
# - Hours saved per month and cost to collect
#
# MVP scope (90 days)
# - Connect to QBO/NetSuite; ingest open invoices and supporting docs
# - Support 3 portals end-to-end: submit, status check, doc upload, remittance retrieval
# - Handle top 5 exceptions and generate human-in-the-loop escalations
# - Email automation to AP with evidence packs; basic phone follow-up for status checks
# - Dashboard with invoice pipeline, blockers, and ROI metrics
#
# Risks and mitigations
# - Portal ToS/anti-bot: obtain explicit customer authorization; use sanctioned APIs/SR-automations where available; detect bot friction and route to human
# - Data security: SOC 2, SSO, vault secrets, step-level audit logs, PII redaction
# - Action safety: approvals on irreversible actions; test-sandbox mode per portal
# - Variability across portals: start with the heaviest-volume portals; build reusable selectors and fallback to human review on unknown states
#
# Go-to-market
# - Vertical focus: suppliers to big-box retail and large OEMs (highest portal pain)
# - Land-and-expand via finance ops teams; offer “prove-the-ROI” pilot on a subset of customers/invoices
# - Pricing: per-invoice processed plus uplift on recovered short-pays; or tiered SaaS + usage
#
# Why this wedge is defensible
# - Building and maintaining reliable portal automations and exception playbooks creates a durable connector moat and labeled edge-case data
# - Clear financial outcomes make payback obvious, supporting premium pricing and sticky expansion across additional portals/customers
#
# If you want, I can turn this into a one-page MVP spec or a pilot plan targeting a specific industry and portal set.

# %%
# Step 2: Ask for a pain point within that business area
messages = [{"role": "user", "content": f"Within the business area of {business_idea}, what is a major pain point in that industry?"}]

response = openai.chat.completions.create(
    model="gpt-5",
    messages=messages
)

pain_point = response.choices[0].message.content
print("Pain Point: ", pain_point)
# Out:
# Pain Point:  Industry: CPG suppliers selling into big-box retail (e.g., Walmart, Target, Costco, Kroger via Retail Link + EDI 850/856/810/820)
#
# Major pain point: Retail deductions/chargebacks (short-pays) and the dispute process
#
# Why it hurts
# - OTIF/shortage/compliance deductions hit 2–6%+ of revenue; disputes are time-bound and code-heavy
# - Root causes span ASN mismatches, receiving errors, label/compliance issues, price/pack changes
# - Details live across 820 remittances and retailer portals; evidence (POD/BOL/appointment confirmations, carrier PRO, photos, contracts) is scattered
# - Teams burn hours reconciling claims and miss recovery windows; DSO rises and cash is unpredictable
#
# How the agent helps
# - Monitors 820 remittances and retailer portals (e.g., Retail Link) to detect new deductions and pull claim detail
# - Auto-assembles evidence packs (POD/BOL/ASN vs receipt, OTIF appointment logs, carrier docs)
# - Files and tracks disputes per retailer rules; follows up via portal/email/phone, escalates when needed
# - Reconciles recovered amounts and reason codes back to ERP; maintains accruals and analytics
#
# Key success metrics
# - Deduction recovery rate and dollars recovered
# - Dispute cycle time and first-pass acceptance rate
# - Touchless dispute rate and hours saved
# - DSO reduction and short-pay variance vs plan
#
# If helpful, I can turn this into a one-page MVP spec/pilot focused on Walmart/Target first (Retail Link + EDI 856/810/820) integrated with your ERP. Which retailers and ERP are you on today?

# %%
# Step 3: Ask for a solution to that pain point

messages = [{"role": "user", "content": f"Given the business area of {business_idea} and the pain point of {pain_point}, propose a solution that an agentic AI could provide to solve that pain point. Provide a detailed description of the solution."}]

response = openai.chat.completions.create(
    model= "gpt-5",
    messages=messages
)

agentic_solution = response.choices[0].message.content
print("Agentic AI Solution: ", agentic_solution)
# Out:
# Agentic AI Solution:  Here’s a concrete agentic AI solution purpose-built to reduce retail deductions/chargebacks and speed dispute recovery for CPG suppliers selling into big-box retail (e.g., Walmart/Target via Retail Link + EDI 850/856/810/820).
#
# Solution overview
# - Outcome: Recover more dollars, faster, with fewer manual hours. Stabilize cash by shrinking short-pay variance and DSO related to deductions.
# - Scope: Detect all short-pays/deductions, auto-assemble evidence, file/track disputes per retailer rules, and reconcile recovered amounts to ERP.
#
# Agent team (what the agent actually does)
# - Deduction Detector
#   - Monitors EDI 820 remittances and retailer portals (e.g., Retail Link) for new deductions; normalizes reason codes and due dates.
#   - Matches each deduction to PO/invoice/ASN/shipment, even when references are partial or netted across multiple invoices.
# - Evidence Assembler
#   - Auto-collects and validates supporting artifacts: PO, invoice, ASN vs DC receipt variances, BOL/POD, appointment confirmations, carrier PRO, photos/labels, contracts/price agreements, OTIF logs.
#   - Reconciles quantities and timestamps; highlights mismatches that support a dispute.
# - Dispute Filer
#   - Files disputes through retailer portals (Retail Link, Partners Online) using retailer-specific templates and evidence requirements.
#   - Tracks case IDs/status; diarizes follow-ups; opens AP tickets and sends emails where portals require.
# - Follow-up and Escalation
#   - Schedules callbacks, places status-check calls (voice agent), and escalates unresolved/aged cases with concise briefs for a human approver to intervene.
# - Reconciliation and Analytics
#   - On recovery, reconciles payments to ERP (credit memos/adjustments) and updates reason-code analytics, accruals, and recovery dashboards.
#   - Feeds root-cause insights (e.g., ASN error hotspots) to ops teams.
#
# End-to-end workflow
# 1) Ingest and normalize
# - Pull open invoices, shipments, ASNs, and contracts from ERP/WMS/contract store.
# - Ingest EDI remittances (820) from VAN/translator; parse deduction lines, reason codes, check numbers, dates, netting.
# - Poll portals for claim detail and evidence requirements; cache retailer rulebooks.
# 2) Detect and match
# - Deterministic matching using PO#, invoice#, ship-to/DC, check#, dates, amounts; fall back to fuzzy matching with reasoner to resolve ambiguous nets.
# - Create a Deduction Case with normalized reason code, deadline, dollar amount, linked documents, and confidence score.
# 3) Triage and prioritization
# - Rank by recoverability and deadline: high-dollar shortages with strong ASN/POD vs receiving errors; price variances where contract backs your price; OTIF with valid appointment and arrival timestamps.
# - Auto-approve low-risk, high-confidence filings; route edge cases for human review.
# 4) Evidence assembly
# - Shortage: Compare 856 vs retailer receipt; pull BOL, POD with seal intact, carrier PRO, unload times; highlight scan counts vs expected.
# - Price: Extract price terms from contracts/price lists; compare to invoice and PO; include change-effective dates.
# - Compliance/OTIF: Pull appointment confirmations, check-in/out logs, retailer OTIF portal screenshots, exception codes; attach label photos and GS1 specs when relevant.
# - Freight: Gather routing guide, prepaid/collect terms, carrier invoices, routing compliance.
# - Generate a single “evidence pack” with narrative, tables, and labeled exhibits; store signed PDFs with portal-required formats.
# 5) File and track disputes
# - Log into retailer portal; select correct claim/deduction case; upload evidence and complete required fields per reason code.
# - If portal disallows automation or triggers bot friction, switch to sanctioned API/SR-automation or prepare a human-in-the-loop clickthrough with prefilled fields.
# - Send confirmation emails and log case IDs; create follow-up tasks on SLAs.
# 6) Follow-ups and escalations
# - Email cadence to AP contacts with case context; open portal tickets when statuses stall.
# - Voice agent calls AP for status, logs call notes, and schedules callbacks.
# - Escalate with a one-page brief for human owner when appeal or multiple submissions are required.
# 7) Reconcile recoveries
# - Monitor 820s and portal outcomes; on recovery or partial acceptance, post adjustments in ERP, update deduction disposition, and close the case with annotated learning.
# - Update accruals and reason-code analytics; surface recurring defects to ops (ASN mapping, labeling, carrier performance).
#
# Integrations and tools
# - ERP/accounting: NetSuite, QBO, Sage Intacct, SAP B1, Microsoft Dynamics (read: invoices, POs, shipments; write: adjustments, memos).
# - EDI: 850/855/856/810/820 via SPS, TrueCommerce, DiCentral, Boomi (parser emits normalized objects).
# - Portals: Phase 1 focus on Walmart Retail Link and Target Partners Online; later Kroger, Costco.
# - Email/Calendar: Gmail/O365 for AP outreach and callback holds.
# - Voice: Telephony (e.g., Twilio) with call recording and scripted status-checks.
# - Document AI: OCR/LLM parsers for BOL/POD/remittance PDFs; RAG over contracts, SLAs, routing guides.
# - Browser automation: Headless browser with reusable selectors; human-in-the-loop mode for high-friction steps.
# - Storage and audit: Encrypted blob store for artifacts; step-level audit logs; approvals for irreversible actions.
#
# Data model (simplified)
# - Invoice, PO, Shipment (ASN), Delivery, Deduction Case, Dispute Filing, Evidence Artifact, Retailer Rulebook, Contact, Touchpoint, Recovery Transaction.
# - Link graph: Invoice -> Shipment -> ASN -> Delivery -> Deduction Case(s) -> Dispute Filing(s) -> Recovery Transaction(s).
#
# Exception library (starter mapping)
# - Shortage/Receiving error: Cross-check 856 vs receipt; BOL/POD; PRO; unloading logs; request DC recount when evidence strong.
# - Price/Terms: Contract price vs invoice/PO; effective dates; promo agreements; item/pack conversion.
# - OTIF/Compliance: Appointment confirmations; arrival times; carrier delay codes; label/ASN compliance docs.
# - Freight/Allowances: Routing guide terms; accessorials; freight prepaid/collect evidence.
# - Duplicate invoice/mismatch: Prior payments, invoice uniqueness checks, remittance mapping.
#
# Human-in-the-loop controls
# - Confidence thresholds for auto-file. Require human approval for high-dollar claims, low-confidence matches, or brand-new reason codes.
# - Redlines of evidence packs and portal submissions before finalization.
# - Sandbox/test mode per retailer; dry-run with simulated filings.
#
# Safety and compliance
# - SOC 2 practices; SSO/SAML; vault secrets for credentials; principle of least privilege.
# - Respect portal ToS; use sanctioned APIs where offered; detect bot defenses and route to supervised actions.
# - PII redaction in documents; immutable audit log of every step and portal action.
#
# Key success metrics
# - Deduction recovery rate (% and $) and net recovered vs baseline.
# - Dispute cycle time, first-pass acceptance rate, touchless dispute rate.
# - Hours saved/month and cost-to-collect reduction.
# - DSO reduction attributable to deductions and short-pay variance vs plan.
# - Root-cause trend reduction (e.g., ASN mismatch rate, labeling errors).
#
# MVP in 90 days (Retail Link + Target first)
# - Weeks 0–2: Connect ERP and EDI; import 6–12 months of invoices/ASNs; set up secure portal access; catalog top reason codes and deadlines; define approval thresholds.
# - Weeks 2–4: Build matching engine and deduction normalizer; initial dashboard (pipeline, dollars at risk, deadlines).
# - Weeks 4–6: Evidence pack templates for top codes (shortage, price, OTIF/compliance, freight); document parsers for BOL/POD/remittance; contract RAG.
# - Weeks 6–8: Portal automation for filing and status checks; email/voice follow-ups; human-in-the-loop UI; audit logging.
# - Weeks 8–12: Run live on a subset of customers; measure recovery and cycle time; refine playbooks and selectors; enable ERP reconciliation writes.
#
# Pilot scope and success criteria
# - Scope: Walmart and Target deductions for 8–12 weeks on last 90 days of invoices; integrate with your ERP and EDI.
# - Targets:
#   - +20–40% lift in recovery rate on targeted reason codes.
#   - 50%+ reduction in average dispute cycle time.
#   - 60–80% touchless filing on standard shortage/price claims with high-confidence evidence.
#   - 30–50 hours/month AR analyst time saved per 1,000 invoices.
# - Executive readout: Dollars recovered, backlog burned, ROI, and top 3 root-cause fixes.
#
# Why this works and scales
# - Agent persistence across portals and EDI gives consistent follow-through on deadlines.
# - Retailer-specific playbooks and evidence templates compress cycle time and increase first-pass wins.
# - Connector and selector library plus labeled edge-case data form a defensible moat; performance improves with each filing.
#
# What I need to tailor this to you
# - Your ERP and EDI provider (VAN/translator), and which retailers/portals you use today.
# - Top 3 deduction reason codes by dollars, and sample artifacts (one full invoice/PO/ASN/BOL/POD set; a few 820s).
# - Your approval thresholds and any restricted portals needing human-only execution.
#
# If useful, I can turn this into a one-page MVP spec and a pilot plan targeted at Walmart/Target (Retail Link + EDI 856/810/820) integrated with your ERP, including detailed evidence templates and dispute workflows per reason code.
